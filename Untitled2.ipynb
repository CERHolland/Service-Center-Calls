# %%
import pandas as pd
import numpy as np

# %%
j=0
while j < 10:
  j+=1
  if j%3 == 0:
    continue
  print(j)
# Out:
# 1
# 2
# 4
# 5
# 7
# 8
# 10

# %%
my_money = 40
season = 'winter'
if my_money >=50:
  print('you can get a new game')
elif my_money >= 5 and season =='summer':
  print('you can get ice cream')
elif my_money >5 and season =='winter':
  print('you can get a beer')
else:
  print('keep saving')
# Out:
# you can get a beer

# %%
3+((7+5)/4)*2
# Out:
# 9.0

# %%
def multiply_three_numbers (a,b,c):
  result = a*b*c
  return result
print(multiply_three_numbers(2,3,4))
# Out:
# 24

# %%
new_var = df['school'].replace (['BYU'with'Brigham Young'],['UVU with 'Utha Valley])
# Out:
#   File "/tmp/ipython-input-354943564.py", line 1
#     new_var = df['school'].replace (['BYU'with'Brigham Young'],['UVU with 'Utha Valley])
#                                           ^
# SyntaxError: invalid syntax

# %%
cities = ['beiging', 'tokyo','amsterdam','rome','paris','seoul']
for city in cities:
  if city =='amsterdam':
    city = city + '!!!'
  elif city == 'paris':
    pass
  print (city)
# Out:
# beiging
# tokyo
# amsterdam!!!
# rome
# paris
# seoul

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize =(8,4))
sns.histplot(x='meta_score',data=viz_df, color = 'purple')
plt.show
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3284969710.py in <cell line: 0>()
#       1 plt.figure(figsize =(8,4))
# ----> 2 sns.histplot(x='meta_score',data=viz_df, color = 'purple')
#       3 plt.show
#
# NameError: name 'viz_df' is not defined

# %%
plt.figure(figsize =(8,4))
sns.histplot(x='IMDB_Rating',data=viz_df, color = 'purple',bins=18)
plt.show
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2672269164.py in <cell line: 0>()
#       1 plt.figure(figsize =(8,4))
# ----> 2 sns.histplot(x='IMDB_Rating',data=viz_df, color = 'purple',bins=18)
#       3 plt.show
#
# NameError: name 'viz_df' is not defined
